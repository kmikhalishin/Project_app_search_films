# %% [markdown]
# # User interface for selecting movies in the database *** Sakila ***

# %% [markdown]
# ### Creater: ** Kirill Mikhalishin **

# %%
# %run search_movies.py
# Out:
# Select a search option:
#
# 1.    <<<   🔍   >>>   Search by keyword or phrase
# 2.    <<<   🎬   >>>   Search by genre
# 3.    <<<   📅   >>>   Search by year
# 4.    <<<   🧑   >>>   Search by actor
# 5.    <<<   💵   >>>   Movie price categories by genre
# 6.    <<<   🏆   >>>   Top 10 popular movies (most rented in our stores)
# 7.    <<<   🎭   >>>   Top 10 actors (the most frequently seen actors in the movies in our database)
# 8.    <<<   🕒   >>>   Categories of movies by duration
# 9.    <<<   📖   >>>   The last 10 rented movies
#
# Service requests:
#
# 10.   <<<   📊   >>>  Top 3 popular user queries
# 11.   <<<   💬   >>>  Instructions on how to use the program
# 12.   <<<   💬   >>>  Structure of *sakila* base (tables, columns)
# 0.    <<<   ❌   >>>  Exit
# Select an action:  1
# Search by keyword or phrase:
# Enter a key phrase or word:  dog red
# List of movies at your request:
#
#      1. Title: BED HIGHBALL
#         Release year: 2006 | Rating: NC-17
# ...
